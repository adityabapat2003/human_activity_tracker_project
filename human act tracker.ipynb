# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
#Reading the datesets
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.shape
train.columns

test.shape
test.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
pd.crosstab(train.subject , train.Activity)
# Out:
# Activity  LAYING  SITTING  STANDING  WALKING  WALKING_DOWNSTAIRS  \
# subject
# 1             50       47        53       95                  49
# 3             62       52        61       58                  49
# 5             52       44        56       56                  47
# 6             57       55        57       57                  48
# 7             52       48        53       57                  47
# 8             54       46        54       48                  38
# 11            57       53        47       59                  46
# 14            51       54        60       59                  45
# 15            72       59        53       54                  42
# 16            70       69        78       51                  47
# 17            71       64        78       61                  46
# 19            83       73        73       52                  39
# 21            90       85        89       52                  45
# ...

# %%
t1 = train.loc[train['subject']==1]

# %%
t1.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
train.subject.value_counts()
# Out:
# 25    409
# 21    408
# 26    392
# 30    383
# 28    382
# 27    376
# 23    372
# 17    368
# 16    366
# 19    360
# 1     347
# 29    344
# 3     341
# 15    328
# 6     325
# 14    323
# 22    321
# 11    316
# 7     308
# 5     302
# 8     281
# Name: subject, dtype: int64

# %%
#visualizing the data using seaborn
import seaborn as sns
dig = plt.figure(figsize = (32,24))
ax1 = dig.add_subplot(221)
ax1 = sns.stripplot(x = 'Activity' , y= t1.iloc[:,0],data = t1 , jitter = True)
ax2 = dig.add_subplot(222)
ax2 = sns.stripplot(x = 'Activity' , y= t1.iloc[:,1],data = t1 , jitter = True)
plt.show()

# %%
train_df = train
test_df = test

# %%
unique_activities = train_df.Activity.unique()
print("The number of unique activities are {}".format(len(unique_activities)))
replacement = {}
for activity, i in enumerate(unique_activities):
    replacement[activity] = i
train_df.Activity = train_df.Activity.replace(replacement)
test_df.Activity = test_df.Activity.replace(replacement)
train_df.head()
# Out:
# The number of unique activities are 6
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
def sumdata():
    train_values = train_df.values
    test_values = test_df.values
    np.random.shuffle(train_values)
    np.random.shuffle(test_values)
    x_train = train_values[:,:-1]
    x_test = test_values[:,:-1]
    y_train = train_values[:,-1]
    y_test = test_values[:,-1]
    return x_train , x_test , y_train ,y_test

# %%
#using logistic regression model
from sklearn.linear_model import LogisticRegression
x_train , x_test , y_train ,y_test = sumdata()

# %%
model = LogisticRegression(C=10)
model
# Out:
# LogisticRegression(C=10)

# %%
#Testing the model accuracy
model.fit(x_train, y_train)
model.score(x_test , y_test)*100
# Out:
# C:\Users\aditya\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 94.53681710213777
